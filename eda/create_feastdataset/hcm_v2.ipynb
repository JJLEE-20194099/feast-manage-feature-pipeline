# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/process_v1/process_data_8_hcm.csv')

# %%
selected_cols = [c for c in df.columns.tolist() if c not in ['target', 'time']]

# %%
timestamps = df['time'].tolist()
timestamps = pd.Series([pd.Timestamp(item) for item in timestamps])
timestamps = timestamps.to_frame(name="event_timestamp")

# %%
df = pd.concat(objs=[df, timestamps], axis=1)

# %%
df = df.sort_values(by = ['event_timestamp'])
df
# Out:
#        nearest_0_ward  nearest_8_ward  certificateOfLandUseRight  \
# 24760              13              13                          0
# 37121             137             137                          1
# 6893              518             100                          0
# 6401              438              38                          1
# 24402              28             172                          1
# ...               ...             ...                        ...
# 30850             140             140                          1
# 5150              364             364                          1
# 41330             108             100                          1
# 11161             391             391                          1
# 20237             215             215                          0
#
#        nearest_4_district  nearest_7_district  nearest_3_district  \
# 24760                  11                  11                  11
# 37121                  10                  10                  10
# 6893                   11                 100                  11
# 6401                   14                  10                  10
# 24402                  18                   0                  18
# ...                   ...                 ...                 ...
# 30850                  30                  30                  30
# 5150                   30                  30                  30
# 41330                  11                 100                  11
# 11161                  42                  42                  42
# 20237                  10                  10                  10
#
#        nearest_1_district  nearest_6_street  nearest_5_district  \
# 24760                  11               991                  11
# 37121                  10              3100                  10
# 6893                   11               454                  11
# 6401                   14              1990                  10
# 24402                  18              3156                  18
# ...                   ...               ...                 ...
# 30850                  30              1534                  30
# 5150                   30              1095                  30
# 41330                  11               100                  11
# 11161                  42              3350                  42
# 20237                  10              3805                  10
#
#        nearest_2_ward  ...  num_of_marketplace_in_500m_radius  \
# 24760              13  ...                                  1
# 37121             547  ...                                  1
# 6893              518  ...                                  4
# 6401              438  ...                                  0
# 24402              28  ...                                  0
# ...               ...  ...                                ...
# 30850             140  ...                                  0
# 5150              364  ...                                  1
# 41330             488  ...                                  0
# 11161             391  ...                                 -1
# 20237             215  ...                                  0
#
#        distance_hn_LeHongPhong                 time      target  \
# 24760                 8.283059  2023-04-01T00:00:00  450.000000
# 37121                 8.140734  2023-04-03T00:00:00  176.000000
# 6893                  7.975209  2023-05-18T00:00:00  406.250000
# 6401                  8.608067  2023-07-13T00:00:00   69.863014
# 24402                 9.239047  2023-07-14T00:00:00  185.000000
# ...                        ...                  ...         ...
# 30850                 8.980335  2024-02-16T00:00:00  142.000000
# 5150                  8.564434  2024-02-16T00:00:00   89.421158
# 41330                 7.641707  2024-02-16T00:00:00   93.750000
# 11161                 9.398480  2024-02-16T00:00:00   83.333333
# 20237                 8.635133  2024-02-16T00:00:00  291.044776
#
#        gmm_2_component_num_of_restaurant_in_2000m_radius  \
# 24760                                                  1
# 37121                                                  0
# 6893                                                   1
# 6401                                                   0
# 24402                                                  0
# ...                                                  ...
# 30850                                                  0
# 5150                                                   0
# 41330                                                  1
# 11161                                                  0
# 20237                                                  0
#
#        gmm_2_component_num_of_restaurant_in_1000m_radius  \
# 24760                                                  1
# 37121                                                  0
# 6893                                                   1
# 6401                                                   0
# 24402                                                  0
# ...                                                  ...
# 30850                                                  0
# 5150                                                   0
# 41330                                                  1
# 11161                                                  0
# 20237                                                  0
#
#        gmm_3_component_num_of_bank_in_2000m_radius  \
# 24760                                            0
# 37121                                            0
# 6893                                             2
# 6401                                             0
# 24402                                            1
# ...                                            ...
# 30850                                            1
# 5150                                             0
# 41330                                            0
# 11161                                            1
# 20237                                            1
#
#        gmm_2_component_num_of_marketplace_in_2000m_radius  \
# 24760                                                  1
# 37121                                                  1
# 6893                                                   0
# 6401                                                   1
# 24402                                                  1
# ...                                                  ...
# 30850                                                  1
# 5150                                                   1
# 41330                                                  0
# 11161                                                  1
# 20237                                                  1
#
#        gmm_2_component_num_of_cafe_in_1000m_radius  event_timestamp
# 24760                                            1       2023-04-01
# 37121                                            0       2023-04-03
# 6893                                             1       2023-05-18
# 6401                                             0       2023-07-13
# 24402                                            0       2023-07-14
# ...                                            ...              ...
# 30850                                            0       2024-02-16
# 5150                                             0       2024-02-16
# 41330                                            1       2024-02-16
# 11161                                            0       2024-02-16
# 20237                                            0       2024-02-16
#
# [44149 rows x 191 columns]

# %%
full_feat_set = selected_cols

data_df = df[full_feat_set + ['event_timestamp']]
target_df = df[['target'] + ['event_timestamp']]

# %%
realestate_ids = pd.DataFrame(data=list(range(len(data_df))), columns=["realestate_id"])

data_df = pd.concat(objs=[data_df, realestate_ids], axis=1)
target_df = pd.concat(objs=[target_df, realestate_ids], axis=1)

# %%
data_df.to_parquet(path='../../data/data_df_hcm_v2.parquet')
target_df.to_parquet(path='../../data/target_df_hcm_v2.parquet')
