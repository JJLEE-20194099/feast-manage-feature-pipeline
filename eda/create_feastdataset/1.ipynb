# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/process_v1/process_data_7_hcm.csv')

# %%
selected_cols = [c for c in df.columns.tolist() if c not in ['target', 'time']]

# %%
timestamps = df['time'].tolist()
timestamps = pd.Series([pd.Timestamp(item) for item in timestamps])
timestamps = timestamps.to_frame(name="event_timestamp")

# %%
df = pd.concat(objs=[df, timestamps], axis=1)

# %%
df = df.sort_values(by = ['event_timestamp'])
df
# Out:
#        nearest_2_district  nearest_3_street  nearest_6_street  \
# 24794                  11              1087               991
# 37176                  10              2428              3100
# 6905                   11              2850               454
# 6412                   14               848              1990
# 24436                  18              1300              3156
# ...                   ...               ...               ...
# 2697                    1               777              3419
# 22001                  20              2793              2141
# 21481                  13               715              3910
# 10914                  30              3396               676
# 7477                   30               100               100
#
#        nearest_1_district  nearest_8_district  accessibility  \
# 24794                  11                  11              0
# 37176                  10                  10              0
# 6905                   11                 100              0
# 6412                   14                  10              0
# 24436                  18                  18              1
# ...                   ...                 ...            ...
# 2697                    1                   1              3
# 22001                  20                  14              0
# 21481                  13                  13              4
# 10914                  10                  10              0
# 7477                   30                 100              4
#
#        nearest_7_district  typeOfRealEstate  nearest_1_street  nearest_6_ward  \
# 24794                  11                 3              3153              13
# 37176                  10                 3              3190             547
# 6905                  100                 3              1627             279
# 6412                   10                 0              2640             559
# 24436                   0                 1               860             172
# ...                   ...               ...               ...             ...
# 2697                    1                 1              1449             116
# 22001                  20                 3              1187              30
# 21481                  13                 1              3094             303
# 10914                  30                 3               234             140
# 7477                  100                 1              3784             100
#
#        ...  distance_hn_Aeon Mall Shopping Center Tân Phú  \
# 24794  ...                                       8.844290
# 37176  ...                                       8.994285
# 6905   ...                                       8.316257
# 6412   ...                                       9.131750
# 24436  ...                                       9.234733
# ...    ...                                            ...
# 2697   ...                                       8.142022
# 22001  ...                                       9.080495
# 21481  ...                                       9.796663
# 10914  ...                                       9.311393
# 7477   ...                                       9.386921
#
#        num_of_parking_entrance_in_2000m_radius  nearest_2_lat  \
# 24794                                        2      10.792875
# 37176                                        0      10.787188
# 6905                                         0      10.765089
# 6412                                         5      10.808713
# 24436                                        0      10.806146
# ...                                        ...            ...
# 2697                                         0      10.727410
# 22001                                        1      10.805448
# 21481                                        0      10.882365
# 10914                                        0      10.804743
# 7477                                         0      10.811002
#
#        distance_hn_Công viên Lê Văn Tám  num_of_restaurant_in_500m_radius  \
# 24794                          5.956025                                20
# 37176                          8.306629                                 1
# 6905                           7.880644                               106
# 6412                           7.945040                                 3
# 24436                          8.831937                                 2
# ...                                 ...                               ...
# 2697                           8.979089                                 1
# 22001                          7.627422                                 3
# 21481                          9.339221                                 0
# 10914                          8.760873                                 2
# 7477                           8.912796                                 0
#
#        distance_hn_Đường Lê Lợi, quận 1, TPHCM  \
# 24794                                 7.771465
# 37176                                 8.572820
# 6905                                  6.899570
# 6412                                  8.488024
# 24436                                 8.799135
# ...                                        ...
# 2697                                  8.680754
# 22001                                 8.298848
# 21481                                 9.503459
# 10914                                 8.989615
# 7477                                  9.110137
#
#        num_of_place_of_worship_in_1000m_radius                 time  \
# 24794                                       29  2023-04-01T00:00:00
# 37176                                       30  2023-04-03T00:00:00
# 6905                                        45  2023-05-18T00:00:00
# 6412                                        10  2023-07-13T00:00:00
# 24436                                        4  2023-07-14T00:00:00
# ...                                        ...                  ...
# 2697                                         0  2024-02-16T00:00:00
# 22001                                       18  2024-02-16T00:00:00
# 21481                                        0  2024-02-16T00:00:00
# 10914                                        2  2024-02-16T00:00:00
# 7477                                         1  2024-02-16T00:00:00
#
#            target  event_timestamp
# 24794  450.000000       2023-04-01
# 37176  176.000000       2023-04-03
# 6905   406.250000       2023-05-18
# 6412    69.863014       2023-07-13
# 24436  185.000000       2023-07-14
# ...           ...              ...
# 2697    96.250000       2024-02-16
# 22001  123.595506       2024-02-16
# 21481   51.875000       2024-02-16
# 10914  257.352941       2024-02-16
# 7477   100.000000       2024-02-16
#
# [44209 rows x 187 columns]

# %%
full_feat_set = selected_cols

data_df = df[full_feat_set + ['event_timestamp']]
target_df = df[['target'] + ['event_timestamp']]

# %%
realestate_ids = pd.DataFrame(data=list(range(len(data_df))), columns=["realestate_id"])

data_df = pd.concat(objs=[data_df, realestate_ids], axis=1)
target_df = pd.concat(objs=[target_df, realestate_ids], axis=1)

# %%
data_df.to_parquet(path='../../data/data_df_hcm.parquet')
target_df.to_parquet(path='../../data/target_df_hcm.parquet')
