# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/process_v1/process_data_7_hcm.csv')

# %%
selected_cols = [c for c in df.columns.tolist() if c not in ['target', 'time']]

# %%
timestamps = df['time'].tolist()
timestamps = pd.Series([pd.Timestamp(item) for item in timestamps])
timestamps = timestamps.to_frame(name="event_timestamp")

# %%
df = pd.concat(objs=[df, timestamps], axis=1)

# %%
df = df.sort_values(by = ['event_timestamp'])
df
# Out:
#        certificateOfLandUseRight  nearest_7_street  nearest_1_street  \
# 24794                          0               756              3153
# 37176                          1              3429              3190
# 6905                           0               100              1627
# 6412                           1              1479              2640
# 24436                          1              2642               860
# ...                          ...               ...               ...
# 2697                           1               506              1449
# 22001                          1               311              1187
# 21481                          0              1469              3094
# 10914                          0              3451               234
# 7477                           0               100              3784
#
#        nearest_4_street  nearest_5_district  nearest_2_district  \
# 24794              3249                  11                  11
# 37176              4091                  10                  10
# 6905               2559                  11                  11
# 6412               1506                  10                  14
# 24436              1033                  18                  18
# ...                 ...                 ...                 ...
# 2697               3070                   1                   1
# 22001              1257                  20                  20
# 21481              3241                  13                  13
# 10914              2685                  10                  30
# 7477                100                 100                  30
#
#        nearest_3_ward  nearest_6_ward  typeOfRealEstate  nearest_5_street  \
# 24794              13              13                 3               857
# 37176             137             547                 3              4053
# 6905              247             279                 3               495
# 6412               38             559                 0              3062
# 24436              28             172                 1               208
# ...               ...             ...               ...               ...
# 2697              116             116                 1              3299
# 22001             426              30                 3                91
# 21481             303             303                 1              2372
# 10914             215             140                 3              3708
# 7477              100             100                 1               100
#
#        ...  nearest_0_lon  num_of_marketplace_in_500m_radius  \
# 24794  ...     106.689549                                  1
# 37176  ...     106.654154                                  1
# 6905   ...     106.695660                                  4
# 6412   ...     106.675301                                  0
# 24436  ...     106.747117                                  0
# ...    ...            ...                                ...
# 2697   ...     106.728886                                  0
# 22001  ...     106.687283                                  1
# 21481  ...     106.649759                                  0
# 10914  ...     106.635927                                  0
# 7477   ...     106.627039                                  1
#
#        distance_hn_Cong truong Lam Son  distance_hn_Duong Nguyen Thi Dinh  \
# 24794                         7.647704                           9.124532
# 37176                         8.551525                           9.451413
# 6905                          7.143411                           9.000607
# 6412                          8.428535                           9.320652
# 24436                         8.776880                           8.361810
# ...                                ...                                ...
# 2697                          8.728899                           8.754166
# 22001                         8.216211                           9.179180
# 21481                         9.479880                           9.792999
# 10914                         8.967848                           9.626756
# 7477                          9.091571                           9.693534
#
#        distance_hn_Cong vien Tho Trang  \
# 24794                         7.963574
# 37176                         6.743693
# 6905                          8.375282
# 6412                          7.955750
# 24436                         9.212604
# ...                                ...
# 2697                          9.193616
# 22001                         8.232343
# 21481                         9.298375
# 10914                         8.203352
# 7477                          8.442382
#
#        distance_hn_Cong vien ca Koi Rin Rin Park  \
# 24794                                   9.526549
# 37176                                   9.322935
# 6905                                    9.684633
# 6412                                    9.343365
# 24436                                   9.866166
# ...                                          ...
# 2697                                    9.981511
# 22001                                   9.460706
# 21481                                   8.980503
# 10914                                   9.009110
# 7477                                    8.895794
#
#        num_of_restaurant_in_500m_radius                 time      target  \
# 24794                                20  2023-04-01T00:00:00  450.000000
# 37176                                 1  2023-04-03T00:00:00  176.000000
# 6905                                106  2023-05-18T00:00:00  406.250000
# 6412                                  3  2023-07-13T00:00:00   69.863014
# 24436                                 2  2023-07-14T00:00:00  185.000000
# ...                                 ...                  ...         ...
# 2697                                  1  2024-02-16T00:00:00   96.250000
# 22001                                 3  2024-02-16T00:00:00  123.595506
# 21481                                 0  2024-02-16T00:00:00   51.875000
# 10914                                 2  2024-02-16T00:00:00  257.352941
# 7477                                  0  2024-02-16T00:00:00  100.000000
#
#        event_timestamp
# 24794       2023-04-01
# 37176       2023-04-03
# 6905        2023-05-18
# 6412        2023-07-13
# 24436       2023-07-14
# ...                ...
# 2697        2024-02-16
# 22001       2024-02-16
# 21481       2024-02-16
# 10914       2024-02-16
# 7477        2024-02-16
#
# [44209 rows x 186 columns]

# %%
full_feat_set = selected_cols

data_df = df[full_feat_set + ['event_timestamp']]
target_df = df[['target'] + ['event_timestamp']]

# %%
realestate_ids = pd.DataFrame(data=list(range(len(data_df))), columns=["realestate_id"])

data_df = pd.concat(objs=[data_df, realestate_ids], axis=1)
target_df = pd.concat(objs=[target_df, realestate_ids], axis=1)

# %%
data_df.to_parquet(path='../../data/data_df_hcm.parquet')
target_df.to_parquet(path='../../data/target_df_hcm.parquet')

# %%
pd.read_parquet('/home/long/long/datn-feast/data/realestate_dataset_full_version.parquet')
# Out:
#            target           event_timestamp  realestate_id  \
# 0      450.000000 2023-04-01 00:00:00+00:00          24794
# 1      176.000000 2023-04-03 00:00:00+00:00          37176
# 2      406.250000 2023-05-18 00:00:00+00:00           6905
# 3       69.863014 2023-07-13 00:00:00+00:00           6412
# 4      185.000000 2023-07-14 00:00:00+00:00          24436
# ...           ...                       ...            ...
# 44204   96.250000 2024-02-16 00:00:00+00:00           2697
# 44205  123.595506 2024-02-16 00:00:00+00:00          22001
# 44206   51.875000 2024-02-16 00:00:00+00:00          21481
# 44207  257.352941 2024-02-16 00:00:00+00:00          10914
# 44208  100.000000 2024-02-16 00:00:00+00:00           7477
#
#        certificateOfLandUseRight  nearest_7_street  nearest_1_street  \
# 0                              0               756              3153
# 1                              1              3429              3190
# 2                              0               100              1627
# 3                              1              1479              2640
# 4                              1              2642               860
# ...                          ...               ...               ...
# 44204                          1               506              1449
# 44205                          1               311              1187
# 44206                          0              1469              3094
# 44207                          0              3451               234
# 44208                          0               100              3784
#
#        nearest_4_street  nearest_5_district  nearest_2_district  \
# 0                  3249                  11                  11
# 1                  4091                  10                  10
# 2                  2559                  11                  11
# 3                  1506                  10                  14
# 4                  1033                  18                  18
# ...                 ...                 ...                 ...
# 44204              3070                   1                   1
# 44205              1257                  20                  20
# 44206              3241                  13                  13
# 44207              2685                  10                  30
# 44208               100                 100                  30
#
#        nearest_3_ward  ...  distance_hn_Le Van Sy  nearest_4_lon  \
# 0                  13  ...              13.990993     106.689818
# 1                 137  ...              13.990922     106.652100
# 2                 247  ...              13.993378     106.694393
# 3                  38  ...              13.989137     106.676905
# 4                  28  ...              13.990457     106.744331
# ...               ...  ...                    ...            ...
# 44204             116  ...              13.997199     106.731023
# 44205             426  ...              13.989439     106.687071
# 44206             303  ...              13.981842     106.652004
# 44207             215  ...              13.988837     106.632644
# 44208             100  ...              13.988486     106.682683
#
#        distance_nearest_4  nearest_0_lon  num_of_marketplace_in_500m_radius  \
# 0                5.369893     106.689549                                  1
# 1                5.487485     106.654154                                  1
# 2                5.311295     106.695660                                  4
# 3                6.549558     106.675301                                  0
# 4                7.044017     106.747117                                  0
# ...                   ...            ...                                ...
# 44204            6.550797     106.728886                                  0
# 44205            5.862890     106.687283                                  1
# 44206            5.631194     106.649759                                  0
# 44207            5.627917     106.635927                                  0
# 44208            6.199661     106.627039                                  1
#
#        distance_hn_Cong truong Lam Son  distance_hn_Duong Nguyen Thi Dinh  \
# 0                             7.647704                           9.124532
# 1                             8.551525                           9.451413
# 2                             7.143411                           9.000607
# 3                             8.428535                           9.320652
# 4                             8.776880                           8.361810
# ...                                ...                                ...
# 44204                         8.728899                           8.754166
# 44205                         8.216211                           9.179180
# 44206                         9.479880                           9.792999
# 44207                         8.967848                           9.626756
# 44208                         9.091571                           9.693534
#
#        distance_hn_Cong vien Tho Trang  \
# 0                             7.963574
# 1                             6.743693
# 2                             8.375282
# 3                             7.955750
# 4                             9.212604
# ...                                ...
# 44204                         9.193616
# 44205                         8.232343
# 44206                         9.298375
# 44207                         8.203352
# 44208                         8.442382
#
#        distance_hn_Cong vien ca Koi Rin Rin Park  \
# 0                                       9.526549
# 1                                       9.322935
# 2                                       9.684633
# 3                                       9.343365
# 4                                       9.866166
# ...                                          ...
# 44204                                   9.981511
# 44205                                   9.460706
# 44206                                   8.980503
# 44207                                   9.009110
# 44208                                   8.895794
#
#        num_of_restaurant_in_500m_radius
# 0                                    20
# 1                                     1
# 2                                   106
# 3                                     3
# 4                                     2
# ...                                 ...
# 44204                                 1
# 44205                                 3
# 44206                                 0
# 44207                                 2
# 44208                                 0
#
# [44209 rows x 186 columns]
