# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/process_v1/process_data_7_hcm.csv')

# %%
selected_cols = [c for c in df.columns.tolist() if c not in ['target', 'time']]

# %%
timestamps = df['time'].tolist()
timestamps = pd.Series([pd.Timestamp(item) for item in timestamps])
timestamps = timestamps.to_frame(name="event_timestamp")

# %%
df = pd.concat(objs=[df, timestamps], axis=1)

# %%
df = df.sort_values(by = ['event_timestamp'])
df
# Out:
#        nearest_3_lat  accessibility  nearest_0_lat  nearest_7_lon  \
# 24794             10              0             10            106
# 37176             10              0             10            106
# 6905              10              0             10            100
# 6412              10              0             10            106
# 24436             10              1             10            106
# ...              ...            ...            ...            ...
# 2697              10              3             10            106
# 22001             10              0             10            106
# 21481             10              4             10            106
# 10914             10              0             10            106
# 7477             100              4             10            100
#
#        typeOfRealEstate  nearest_4_lat  nearest_7_lat  nearest_2_lon  \
# 24794                 3             10             10            106
# 37176                 3             10             10            106
# 6905                  3             10            100            106
# 6412                  0             10             10            106
# 24436                 1             10             10            106
# ...                 ...            ...            ...            ...
# 2697                  1             10             10            106
# 22001                 3             10             10            106
# 21481                 1             10             10            106
# 10914                 3             10             10            106
# 7477                  1            100            100            106
#
#        district  houseDirection  ...  num_of_parking_entrance_in_2000m_radius  \
# 24794        11               0  ...                                        2
# 37176        10               0  ...                                        0
# 6905         11               0  ...                                        0
# 6412         14               1  ...                                        5
# 24436        18               4  ...                                        0
# ...         ...             ...  ...                                      ...
# 2697          1               0  ...                                        0
# 22001        20               0  ...                                        1
# 21481        13               7  ...                                        0
# 10914        10               0  ...                                        0
# 7477         30               1  ...                                        0
#
#        nearest_3_district  distance_hn_Công viên Lê Văn Tám  \
# 24794                11.0                          5.956025
# 37176                10.0                          8.306629
# 6905                 11.0                          7.880644
# 6412                 10.0                          7.945040
# 24436                18.0                          8.831937
# ...                   ...                               ...
# 2697                  1.0                          8.979089
# 22001                14.0                          7.627422
# 21481                13.0                          9.339221
# 10914                10.0                          8.760873
# 7477                  NaN                          8.912796
#
#        num_of_restaurant_in_500m_radius  \
# 24794                                20
# 37176                                 1
# 6905                                106
# 6412                                  3
# 24436                                 2
# ...                                 ...
# 2697                                  1
# 22001                                 3
# 21481                                 0
# 10914                                 2
# 7477                                  0
#
#        distance_hn_Đường Lê Lợi, quận 1, TPHCM  nearest_7_ward  \
# 24794                                 7.771465            13.0
# 37176                                 8.572820           137.0
# 6905                                  6.899570             NaN
# 6412                                  8.488024            38.0
# 24436                                 8.799135           482.0
# ...                                        ...             ...
# 2697                                  8.680754           116.0
# 22001                                 8.298848            80.0
# 21481                                 9.503459           399.0
# 10914                                 8.989615            73.0
# 7477                                  9.110137             NaN
#
#        num_of_place_of_worship_in_1000m_radius                 time  \
# 24794                                       29  2023-04-01T00:00:00
# 37176                                       30  2023-04-03T00:00:00
# 6905                                        45  2023-05-18T00:00:00
# 6412                                        10  2023-07-13T00:00:00
# 24436                                        4  2023-07-14T00:00:00
# ...                                        ...                  ...
# 2697                                         0  2024-02-16T00:00:00
# 22001                                       18  2024-02-16T00:00:00
# 21481                                        0  2024-02-16T00:00:00
# 10914                                        2  2024-02-16T00:00:00
# 7477                                         1  2024-02-16T00:00:00
#
#            target  event_timestamp
# 24794  450.000000       2023-04-01
# 37176  176.000000       2023-04-03
# 6905   406.250000       2023-05-18
# 6412    69.863014       2023-07-13
# 24436  185.000000       2023-07-14
# ...           ...              ...
# 2697    96.250000       2024-02-16
# 22001  123.595506       2024-02-16
# 21481   51.875000       2024-02-16
# 10914  257.352941       2024-02-16
# 7477   100.000000       2024-02-16
#
# [44209 rows x 187 columns]

# %%
full_feat_set = selected_cols

target_df = pd.DataFrame(data=df.target, columns=["target"])
data_df = df[full_feat_set + ['event_timestamp']]

# %%
realestate_ids = pd.DataFrame(data=list(range(len(data_df))), columns=["realestate_id"])

data_df = pd.concat(objs=[data_df, realestate_ids], axis=1)
target_df = pd.concat(objs=[target_df, realestate_ids], axis=1)

# %%
data_df.to_parquet(path='../../data/data_df_hcm.parquet')
target_df.to_parquet(path='../../data/target_df_hcm.parquet')
