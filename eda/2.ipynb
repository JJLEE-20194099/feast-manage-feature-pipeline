# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/realestate_dataset_1.parquet')
df
# Out:
#             target                  event_timestamp  realestate_id  \
# 0      2111.111111 1907-05-01 06:11:00.877512+00:00              0
# 1      5111.111111 1907-05-02 06:11:00.877512+00:00              1
# 2      3888.888889 1907-05-03 06:11:00.877512+00:00              2
# 3      1722.222222 1907-05-04 06:11:00.877512+00:00              3
# 4      3666.666667 1907-05-05 06:11:00.877512+00:00              4
# ...            ...                              ...            ...
# 42770   490.196078 2024-06-05 06:11:00.877512+00:00          42770
# 42771   186.868687 2024-06-06 06:11:00.877512+00:00          42771
# 42772   329.218107 2024-06-07 06:11:00.877512+00:00          42772
# 42773   204.017577 2024-06-08 06:11:00.877512+00:00          42773
# 42774    14.648438 2024-06-09 06:11:00.877512+00:00          42774
#
#        num_of_bathroom  district  num_of_bedroom  used_area
# 0                  1.0         0             2.0       30.0
# ...
